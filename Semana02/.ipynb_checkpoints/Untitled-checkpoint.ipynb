# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.display import Image
Image("letra I.png")

# %%
I = np.array([(0,0,1),(3,0,1),(3,1,1),(2,3,1),(2,4,1),(3,4,1),(3,5,1),(0,5,1),(9,1,1)])

# %%
# Matriz de cambio de escala
s=3 #Escalar
S=np.array ([[s, 0, 0.], [0., s, 0.] ,[0. , 0., 1.]])

# %%
# Matriz de deformación horizontal/vertical

h ,v =-4, 3
D=np.array ([[1. , h, 0.] ,[v, 1., 0.] ,[0. , 0., 1.]])
D
# Out:
# array([[ 1., -4.,  0.],
#        [ 3.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %%
ax= plt.gca() 
plt.plot(I[:, 0], I[:, 1],color="blue", label="Original") 
plt.plot(T[0], T[1], color="red", label="Transformado") 
ax.set_xticks (np.arange(-3,12,1)) 
ax.set_yticks (np.arange(-3,17,1)) 
ax.set_aspect("equal", adjustable="box") 
plt.grid() 
plt.rcParams["figure.figsize"] = (8,4) 
plt.legend(loc="upper center") 
plt.show()
