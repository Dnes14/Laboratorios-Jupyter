# %% [markdown]
# # SEMANA 2: TRANSFORMACIÓN LINEAL. TEOREMA FUNDAMENTAL. ESPACIO DE LASTRANSFORMACIONES. MATRIZ ASOCIADA
# <h1 align="center">(LABORATORIO CALIFICADO)</h1>
#
# ## ALUMNOS:
# - Escriba Flores, Daniel Agustin
# - Palma Gongora, Yllari Fiorella
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## A: Inserte la figura anterior como imagen en su Jupyter notebook y almacene los pares ordenados que la forman en una matriz.

# %%
from IPython.display import Image
Image("letra I.png")

# %%
# Coordenadas de la letra I
I = np.array([(0,0,1), (3,0,1), (3,1,1), (2,1,1), (2,4,1), (3,4,1), (3,5,1), 
              (0,5,1), (0,4,1), (1,4,1), (1,1,1), (0,1,1), (0,0,1)])
I
# Out:
# array([[0, 0, 1],
#        [3, 0, 1],
#        [3, 1, 1],
#        [2, 1, 1],
#        [2, 4, 1],
#        [3, 4, 1],
#        [3, 5, 1],
#        [0, 5, 1],
#        [0, 4, 1],
#        [1, 4, 1],
#        [1, 1, 1],
#        [0, 1, 1],
#        [0, 0, 1]])

# %% [markdown]
# ## B: Aplique una transformación de escala con s = 3 y grafique la imagen original junto con su versión transformada.

# %%
# Matriz de cambio de escala
s=3 #Escalar
S=np.array ([[s, 0., 0.], [0., s, 0.] ,[0. , 0., 1.]])
S
# Out:
# array([[3., 0., 0.],
#        [0., 3., 0.],
#        [0., 0., 1.]])

# %%
# Aplicar la transformación

Ix = [] 
Iy = [] 
for row in I: 
    output_rown = (S.dot(row)) 
    x, y, z = output_rown 
    Ix.append(x) 
    Iy.append(y) 
T = [Ix, Iy]

# %%
#Graficamos

ax= plt.gca() 
plt.plot(I[:, 0], I[:, 1],color="blue", label="Original") 
plt.plot(T[0], T[1], color="red", label="Transformado") 
ax.set_xticks (np.arange(-3,12,1)) 
ax.set_yticks (np.arange(-3,23,1)) 
ax.set_aspect("equal", adjustable="box") 
plt.grid() 
plt.rcParams["figure.figsize"] = (8,4) 
plt.legend(loc="upper center") 
plt.show()

# %% [markdown]
# ## C: Aplique una transformación de deformación horizontal/vertical con h = –4 y v = 3, y grafique la imagen original junto con su versión transformada.

# %%
# Matriz de deformación horizontal/vertical
h = -4
v =  3
D = np.array([[1., h, 0.], [v, 1., 0.], [0., 0., 1.]])
D
# Out:
# array([[ 1., -4.,  0.],
#        [ 3.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %%
# Aplicar la transformación
Ix1 = [] 
Iy1 = [] 
for row in I: 
    output_rown = D.dot(row)
    x, y, z = output_rown
    Ix1.append(x) 
    Iy1.append(y) 
T2 = [Ix1, Iy1]

# %%
#Graficamos

ax= plt.gca() 
plt.plot(I[:, 0], I[:, 1],color="blue", label="Original") 
plt.plot(T2[0], T2[1], color="red", label="Transformado") 
ax.set_xticks (np.arange(-20,15,1)) 
ax.set_yticks (np.arange(-10,25,1)) 
ax.set_aspect("equal", adjustable="box") 
plt.grid() 
plt.rcParams["figure.figsize"] = (8,4) 
plt.legend(loc="upper center") 
plt.show()
